# %% [markdown]
# <a href="https://colab.research.google.com/github/Connoroverbay/DS-4002-Project1/blob/main/Project_1_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Project 1 Code: Group 3

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn as sk

# %%
df = pd.read_csv("/content/Cancer Research Grants.csv")
df.head(10)
# Out:
#   ----------------------------------------------------------------------------------------------------------------  \
# 0                                   Search Criteria:
# 1                                  Fiscal Year: 2024
# 2                                         Admin: Yes
# 3                       Agency/Institute/Center: NCI
# 4                                    Award Type: New
# 5  ----------------------------------------------...
# 6                        NIH Spending Categorization
# 7                          No NIH Category available
# 8                          No NIH Category available
# 9                          No NIH Category available
#
#                                           Unnamed: 1        Unnamed: 2  \
# 0                                                NaN               NaN
# 1                                                NaN               NaN
# 2                                                NaN               NaN
# 3                                                NaN               NaN
# 4                                                NaN               NaN
# 5                                                NaN               NaN
# 6                                      Project Title  Administering IC
# 7  eDyNAmiC (extrachromosomal DNA in Cancer) - Un...               NCI
# 8  SCH: Individualized learning and prediction fo...               NCI
# 9  SCH: Individualized learning and prediction fo...               NCI
#
#        Unnamed: 3                    Unnamed: 4          Unnamed: 5  \
# 0             NaN                           NaN                 NaN
# 1             NaN                           NaN                 NaN
# 2             NaN                           NaN                 NaN
# 3             NaN                           NaN                 NaN
# 4             NaN                           NaN                 NaN
# 5             NaN                           NaN                 NaN
# 6  Application ID  Program Official Information  Project Start Date
# 7        11128010              FINGERMAN, IAN M       6/1/2024 0:00
# 8        11064395          WOLFF-HUGHES, DANA L       7/1/2024 0:00
# 9        11064395          WOLFF-HUGHES, DANA L       7/1/2024 0:00
#
#          Unnamed: 6                                Unnamed: 7  \
# 0               NaN                                       NaN
# 1               NaN                                       NaN
# 2               NaN                                       NaN
# 3               NaN                                       NaN
# 4               NaN                                       NaN
# 5               NaN                                       NaN
# 6  Project End Date                             Study Section
# 7    5/31/2025 0:00                              ZCA1-SRC(99)
# 8    6/30/2028 0:00  Special Emphasis Panel[ZRG1-IVBH-N(50)R]
# 9    6/30/2028 0:00  Special Emphasis Panel[ZRG1-IVBH-N(50)R]
#
#              Unnamed: 8                   Unnamed: 9  ...     Unnamed: 23  \
# 0                   NaN                          NaN  ...             NaN
# 1                   NaN                          NaN  ...             NaN
# 2                   NaN                          NaN  ...             NaN
# 3                   NaN                          NaN  ...             NaN
# 4                   NaN                          NaN  ...             NaN
# 5                   NaN                          NaN  ...             NaN
# 6  Contact PI Person ID  Contact PI / Project Leader  ...  ARRA Indicator
# 7               9811494             VENTURA, ANDREA   ...               N
# 8               9839722                   QU, ANNIE   ...               N
# 9               9839722                   QU, ANNIE   ...               N
#
#   Unnamed: 24        Unnamed: 25  Unnamed: 26 Unnamed: 27  \
# 0         NaN                NaN          NaN         NaN
# 1         NaN                NaN          NaN         NaN
# 2         NaN                NaN          NaN         NaN
# 3         NaN                NaN          NaN         NaN
# 4         NaN                NaN          NaN         NaN
# 5         NaN                NaN          NaN         NaN
# 6   CFDA Code  Funding Mechanism  Fiscal Year  Total Cost
# 7         393              Other         2024      166232
# 8         393      Non-SBIR/STTR         2024      299988
# 9         393      Non-SBIR/STTR         2024      299988
#
#                  Unnamed: 28    Unnamed: 29     Unnamed: 30       Unnamed: 31  \
# 0                        NaN            NaN             NaN               NaN
# 1                        NaN            NaN             NaN               NaN
# 2                        NaN            NaN             NaN               NaN
# 3                        NaN            NaN             NaN               NaN
# 4                        NaN            NaN             NaN               NaN
# 5                        NaN            NaN             NaN               NaN
# 6  Total Cost (Sub Projects)  Funding IC(s)  Direct Cost IC  InDirect Cost IC
# 7                                       NCI           94450             71782
# 8                                        OD           66234             33766
# 9                                       NCI          132459             67529
#
#      Unnamed: 32
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6  Total Cost IC
# 7         166232
# 8         100000
# 9         199988
#
# [10 rows x 33 columns]

# %%
# prompt: drop first 5 rows

df1 = df.iloc[6:]
df1.head(5)
# Out:
#    ----------------------------------------------------------------------------------------------------------------  \
# 6                         NIH Spending Categorization
# 7                           No NIH Category available
# 8                           No NIH Category available
# 9                           No NIH Category available
# 10                          No NIH Category available
#
#                                            Unnamed: 1        Unnamed: 2  \
# 6                                       Project Title  Administering IC
# 7   eDyNAmiC (extrachromosomal DNA in Cancer) - Un...               NCI
# 8   SCH: Individualized learning and prediction fo...               NCI
# 9   SCH: Individualized learning and prediction fo...               NCI
# 10  SCH: Robust Multimodal Longitudinal AI for Enh...               NCI
#
#         Unnamed: 3                    Unnamed: 4          Unnamed: 5  \
# 6   Application ID  Program Official Information  Project Start Date
# 7         11128010              FINGERMAN, IAN M       6/1/2024 0:00
# 8         11064395          WOLFF-HUGHES, DANA L       7/1/2024 0:00
# 9         11064395          WOLFF-HUGHES, DANA L       7/1/2024 0:00
# 10        11063443         SKARLUPKA, AMANDA LEE       8/1/2024 0:00
#
#           Unnamed: 6                                Unnamed: 7  \
# 6   Project End Date                             Study Section
# 7     5/31/2025 0:00                              ZCA1-SRC(99)
# 8     6/30/2028 0:00  Special Emphasis Panel[ZRG1-IVBH-N(50)R]
# 9     6/30/2028 0:00  Special Emphasis Panel[ZRG1-IVBH-N(50)R]
# 10    7/31/2028 0:00  Special Emphasis Panel[ZRG1-IVBH-N(50)R]
#
#               Unnamed: 8                   Unnamed: 9  ...     Unnamed: 23  \
# 6   Contact PI Person ID  Contact PI / Project Leader  ...  ARRA Indicator
# 7                9811494             VENTURA, ANDREA   ...               N
# 8                9839722                   QU, ANNIE   ...               N
# 9                9839722                   QU, ANNIE   ...               N
# 10              10641231              NABAVI, SHEIDA   ...               N
#
#    Unnamed: 24        Unnamed: 25  Unnamed: 26 Unnamed: 27  \
# 6    CFDA Code  Funding Mechanism  Fiscal Year  Total Cost
# 7          393              Other         2024      166232
# 8          393      Non-SBIR/STTR         2024      299988
# 9          393      Non-SBIR/STTR         2024      299988
# 10         394      Non-SBIR/STTR         2024      310317
#
#                   Unnamed: 28    Unnamed: 29     Unnamed: 30  \
# 6   Total Cost (Sub Projects)  Funding IC(s)  Direct Cost IC
# 7                                        NCI           94450
# 8                                         OD           66234
# 9                                        NCI          132459
# 10                                        OD           34720
#
#          Unnamed: 31    Unnamed: 32
# 6   InDirect Cost IC  Total Cost IC
# 7              71782         166232
# 8              33766         100000
# 9              67529         199988
# 10             15280          50000
#
# [5 rows x 33 columns]

# %%
# prompt: reindex row 6 as the column headers

df1 = df1.rename(columns=df1.iloc[0])
df2 = df1[1:]
df2.head()
# Out:
#    NIH Spending Categorization  \
# 7    No NIH Category available
# 8    No NIH Category available
# 9    No NIH Category available
# 10   No NIH Category available
# 11   No NIH Category available
#
#                                         Project Title Administering IC  \
# 7   eDyNAmiC (extrachromosomal DNA in Cancer) - Un...              NCI
# 8   SCH: Individualized learning and prediction fo...              NCI
# 9   SCH: Individualized learning and prediction fo...              NCI
# 10  SCH: Robust Multimodal Longitudinal AI for Enh...              NCI
# 11  SCH: Robust Multimodal Longitudinal AI for Enh...              NCI
#
#    Application ID Program Official Information Project Start Date  \
# 7        11128010             FINGERMAN, IAN M      6/1/2024 0:00
# 8        11064395         WOLFF-HUGHES, DANA L      7/1/2024 0:00
# 9        11064395         WOLFF-HUGHES, DANA L      7/1/2024 0:00
# 10       11063443        SKARLUPKA, AMANDA LEE      8/1/2024 0:00
# 11       11063443        SKARLUPKA, AMANDA LEE      8/1/2024 0:00
#
#    Project End Date                             Study Section  \
# 7    5/31/2025 0:00                              ZCA1-SRC(99)
# 8    6/30/2028 0:00  Special Emphasis Panel[ZRG1-IVBH-N(50)R]
# 9    6/30/2028 0:00  Special Emphasis Panel[ZRG1-IVBH-N(50)R]
# 10   7/31/2028 0:00  Special Emphasis Panel[ZRG1-IVBH-N(50)R]
# 11   7/31/2028 0:00  Special Emphasis Panel[ZRG1-IVBH-N(50)R]
#
#    Contact PI Person ID Contact PI / Project Leader  ... ARRA Indicator  \
# 7               9811494            VENTURA, ANDREA   ...              N
# 8               9839722                  QU, ANNIE   ...              N
# 9               9839722                  QU, ANNIE   ...              N
# 10             10641231             NABAVI, SHEIDA   ...              N
# 11             10641231             NABAVI, SHEIDA   ...              N
#
#    CFDA Code Funding Mechanism Fiscal Year Total Cost  \
# 7        393             Other        2024     166232
# 8        393     Non-SBIR/STTR        2024     299988
# 9        393     Non-SBIR/STTR        2024     299988
# 10       394     Non-SBIR/STTR        2024     310317
# 11       394     Non-SBIR/STTR        2024     310317
#
#    Total Cost (Sub Projects) Funding IC(s) Direct Cost IC InDirect Cost IC  \
# 7                                      NCI          94450            71782
# 8                                       OD          66234            33766
# 9                                      NCI         132459            67529
# 10                                      OD          34720            15280
# 11                                     NCI         180763            79554
#
#    Total Cost IC
# 7         166232
# 8         100000
# 9         199988
# 10         50000
# 11        260317
#
# [5 rows x 33 columns]

# %%
# prompt: drop rows with Funding IC(s) not = "NCI"

df_nci = df2[df2['Funding IC(s)'] == 'NCI']
df_nci.head()
# Out:
#    NIH Spending Categorization  \
# 7    No NIH Category available
# 9    No NIH Category available
# 11   No NIH Category available
# 12   No NIH Category available
# 15   No NIH Category available
#
#                                         Project Title Administering IC  \
# 7   eDyNAmiC (extrachromosomal DNA in Cancer) - Un...              NCI
# 9   SCH: Individualized learning and prediction fo...              NCI
# 11  SCH: Robust Multimodal Longitudinal AI for Enh...              NCI
# 12  SCH: Synchronous Dyadic Physiological Monitori...              NCI
# 15  SCH: Topological Methods for Breast Tissue Qua...              NCI
#
#    Application ID Program Official Information Project Start Date  \
# 7        11128010             FINGERMAN, IAN M      6/1/2024 0:00
# 9        11064395         WOLFF-HUGHES, DANA L      7/1/2024 0:00
# 11       11063443        SKARLUPKA, AMANDA LEE      8/1/2024 0:00
# 12       11063434         WOLFF-HUGHES, DANA L      8/1/2024 0:00
# 15       11062792              MILLER, DAVID J      8/1/2024 0:00
#
#    Project End Date                             Study Section  \
# 7    5/31/2025 0:00                              ZCA1-SRC(99)
# 9    6/30/2028 0:00  Special Emphasis Panel[ZRG1-IVBH-N(50)R]
# 11   7/31/2028 0:00  Special Emphasis Panel[ZRG1-IVBH-N(50)R]
# 12   7/31/2028 0:00  Special Emphasis Panel[ZRG1-IVBH-N(50)R]
# 15   7/31/2028 0:00  Special Emphasis Panel[ZRG1-IVBH-N(50)R]
#
#    Contact PI Person ID Contact PI / Project Leader  ... ARRA Indicator  \
# 7               9811494            VENTURA, ANDREA   ...              N
# 9               9839722                  QU, ANNIE   ...              N
# 11             10641231             NABAVI, SHEIDA   ...              N
# 12             78467322            ROBERTS, DAVID L  ...              N
# 15             14901305                 CHEN, CHAO   ...              N
#
#    CFDA Code Funding Mechanism Fiscal Year Total Cost  \
# 7        393             Other        2024     166232
# 9        393     Non-SBIR/STTR        2024     299988
# 11       394     Non-SBIR/STTR        2024     310317
# 12       393     Non-SBIR/STTR        2024     299950
# 15       393     Non-SBIR/STTR        2024     300000
#
#    Total Cost (Sub Projects) Funding IC(s) Direct Cost IC InDirect Cost IC  \
# 7                                      NCI          94450            71782
# 9                                      NCI         132459            67529
# 11                                     NCI         180763            79554
# 12                                     NCI         111281            38669
# 15                                     NCI          97207            52793
#
#    Total Cost IC
# 7         166232
# 9         199988
# 11        260317
# 12        149950
# 15        150000
#
# [5 rows x 33 columns]

# %%
df_nci['Funding IC(s)'].describe()
# Out:
# count     1468
# unique       1
# top        NCI
# freq      1468
# Name: Funding IC(s), dtype: object

# %%
# prompt: drop columns named

df2 = df_nci.drop(columns=['NIH Spending Categorization',
                           'Administering IC',
                           'Application ID',
                           'Program Official Information',
                           'Program Official Information',
                           'Project Start Date',
                           'Project End Date',
                           'Study Section',
                           'Other PI or Project Leader(s)',
                           'Primary DUNS',
                           'Primary UEI',
                           'Organization Zip',
                           'ARRA Indicator',
                           'CFDA Code',
                           'Funding Mechanism',
                           'Fiscal Year'])
df2.head()
# Out:
#                                         Project Title Contact PI Person ID  \
# 7   eDyNAmiC (extrachromosomal DNA in Cancer) - Un...              9811494
# 9   SCH: Individualized learning and prediction fo...              9839722
# 11  SCH: Robust Multimodal Longitudinal AI for Enh...             10641231
# 12  SCH: Synchronous Dyadic Physiological Monitori...             78467322
# 15  SCH: Topological Methods for Breast Tissue Qua...             14901305
#
#    Contact PI / Project Leader  \
# 7             VENTURA, ANDREA
# 9                   QU, ANNIE
# 11             NABAVI, SHEIDA
# 12            ROBERTS, DAVID L
# 15                 CHEN, CHAO
#
#                                      Project Abstract  \
# 7   Abstract: eDyNAmiC (extrachromosomal DNA in Ca...
# 9   Recent technological advances in mobile health...
# 11  The overarching objective of this project is t...
# 12  Animal-Assisted Interventions (AAIs) are goal-...
# 15  To better understand breast cancer and its res...
#
#                               Public Health Relevance  \
# 7                                                 NaN
# 9   The proposed project will have potentially pro...
# 11                                                NaN
# 12                                                NaN
# 15                                                NaN
#
#                         Department Organization ID (IPF)  \
# 7                      Unavailable               5079202
# 9   BIOSTATISTICS & OTHER MATH SCI                577504
# 11         ENGINEERING (ALL TYPES)               1506602
# 12  BIOSTATISTICS & OTHER MATH SCI                578204
# 15         ENGINEERING (ALL TYPES)               5992612
#
#                           Organization Name Organization City  \
# 7         SLOAN-KETTERING INST CAN RESEARCH          NEW YORK
# 9           UNIVERSITY OF CALIFORNIA-IRVINE            IRVINE
# 11         UNIVERSITY OF CONNECTICUT STORRS  STORRS-MANSFIELD
# 12  NORTH CAROLINA STATE UNIVERSITY RALEIGH           RALEIGH
# 15    STATE UNIVERSITY NEW YORK STONY BROOK       STONY BROOK
#
#    Organization State              Organization Type Organization Country  \
# 7                  NY            Research Institutes        UNITED STATES
# 9                  CA                COMPUTER CENTER        UNITED STATES
# 11                 CT  BIOMED ENGR/COL ENGR/ENGR STA        UNITED STATES
# 12                 NC  BIOMED ENGR/COL ENGR/ENGR STA        UNITED STATES
# 15                 NY  BIOMED ENGR/COL ENGR/ENGR STA        UNITED STATES
#
#    Total Cost Total Cost (Sub Projects) Funding IC(s) Direct Cost IC  \
# 7      166232                                     NCI          94450
# 9      299988                                     NCI         132459
# 11     310317                                     NCI         180763
# 12     299950                                     NCI         111281
# 15     300000                                     NCI          97207
#
#    InDirect Cost IC Total Cost IC
# 7             71782        166232
# 9             67529        199988
# 11            79554        260317
# 12            38669        149950
# 15            52793        150000

# %%
# prompt: list columns in df2

print(df2.columns)
# Out:
# Index(['Project Title', 'Contact PI Person ID', 'Contact PI / Project Leader',
#        'Project Abstract', 'Public Health Relevance', 'Department',
#        'Organization ID (IPF)', 'Organization Name', 'Organization City',
#        'Organization State', 'Organization Type', 'Organization Country',
#        'Total Cost', 'Total Cost (Sub Projects)', 'Funding IC(s)',
#        'Direct Cost IC', 'InDirect Cost IC', 'Total Cost IC'],
#       dtype='object')

# %%
# prompt: export df2 as a csv

df2.to_csv('df2.csv', index=False)

# %%
# prompt: sort df2 by project title

df2_sorted = df2.sort_values(by=['Project Title'])
df2_sorted.head(20)
# Out:
#                                           Project Title Contact PI Person ID  \
# 929   "SMART" nanoparticle delivery of veratridine o...             10847048
# 1179              2023 SoCal Genome Stability Symposium             10556025
# 693   2024 Annual Conference Grant: American Society...              3056913
# 689   2024 Annual Meeting of the American Society fo...             15646248
# 735           2024 BTEC conference (5/14/24 to 5/17/24)             11264850
# 761   2024 Chromatin Structure and Function Gordon R...              8025133
# 1250  2024 DNA Damage Mutation and Cancer Gordon Res...              8326184
# 754   2024 Intrinsically Disordered Proteins Gordon ...             10831685
# 691   2024 Mutagenesis Gordon Research Conference an...             10118578
# 682   2024 Radionuclide Theranostics for the Managem...             15487881
# 82    21st International Conference of the Society f...             10568482
# 674                   23rd Midwest DNA Repair Symposium              1880454
# 1446  3' RNA modification enzymes regulate tumor ang...              9776729
# 1331  33rd International Workshop on Retroviral Path...              1866427
# 1126      3D In vivo dosimetry for FLASH proton therapy             14424291
# 655   3D Proteomics at Single Cell Resolution with C...              6611541
# 178   3D Spatial Multi-Omics Profiling of Ovarian Ca...              1899826
# 363   3D bioengineered microfluidic platform for res...              6763712
# 523   3D genome reorganization drives cancer develop...             11474116
# 539   3D wearable NIR spectral tomography for early ...              7735441
#
#      Contact PI / Project Leader  \
# 929      REZVANI, KHOSROW SAMUEL
# 1179             CHIOLO, IRENE E
# 693             KINNEY, ANITA Y.
# 689           COLEMAN, WILLIAM B
# 735              OSTROM, QUINN T
# 761            NARLIKAR, GEETA J
# 1250       STARK, JEREMY MICHAEL
# 754               MITTAG, TANJA
# 691              MERRIKH, HOURA
# 682                  ZAN, ELCIN
# 82                LEE, RICHARD T
# 674        STATES, J CHRISTOPHER
# 1446         TAKYAR, SEYEDTAGHI
# 1331          GREEN, PATRICK LEE
# 1126     XIANG, LIANGZHONG SHAWN
# 655            YATES III, JOHN R
# 178                MOK, SAMUEL C
# 363         KITLINSKA, JOANNA B.
# 523      MUZUMDAR, MANDAR DEEPAK
# 539              JIANG, SHUDONG
#
#                                        Project Abstract  \
# 929   Project SummaryColorectal cancer (CRC) has a h...
# 1179  ABSTRACTThe 2023 SoCal Genome Stability Sympos...
# 693   ABSTRACTThe mission of the American Society of...
# 689   The 2024 Annual Meeting of the American Societ...
# 735   ABSTRACT/SUMMARYBrain tumors (malignant and be...
# 761   Project SummaryThis proposal requests support ...
# 1250  SUMMARY. The DNA Damage Mutation and Cancer Go...
# 754   Project Summary/AbstractThe 2022 Gordon Resear...
# 691   Project SummaryThe 2024 Gordon Research Confer...
# 682   Project Summary/AbstractThe Gordon Research Co...
# 82    PROJECT SUMMARY/ABSTRACTThe Society for Integr...
# 674   AbstractThe 23rd Midwest DNA Repair Symposium ...
# 1446  Lung cancer is the leading cause of cancer-rel...
# 1331  Project Summary/AbstractThe International Work...
# 1126  ABSTRACT: This U01 application aims to (1) dev...
# 655   Project Summary/AbstractSomatic mutations alte...
# 178   Research Summary:High-grade serous ovarian can...
# 363   Ewing sarcoma (ES) is a pediatric malignancy w...
# 523   PROJECT SUMMARY/ABSTRACTThe three-dimensional ...
# 539   Prediction of Residual Cancer Burden (RCB) ear...
#
#                                 Public Health Relevance  \
# 929   Public Health RelevanceThis study will develop...
# 1179  PROJECT NARRATIVEMany novel cancer therapies h...
# 693   Project Narrative - Public Health RelevanceThe...
# 689   The Annual Meeting of the American Society for...
# 735   PROJECT NARRATIVEWe propose a 2024 conference ...
# 761   Project NarrativeThe organization of the eukar...
# 1250  NARRATIVE. Several cancer treatment modalities...
# 754   Project NarrativeIntrinsically disordered prot...
# 691   Project NarrativeMutagenesis changes in the DN...
# 682   Project NarrativeCancer is an increasing threa...
# 82    Project NarrativeThe Society for Integrative O...
# 674   Project NarrativeDNA damage contributes to the...
# 1446  Vascular cells inside the tumor or tumor endot...
# 1331  Project NarrativeRetroviruses have long been r...
# 1126  The field of FLASH radiotherapy has experience...
# 655   Project narrativeSomatic mutations that alter ...
# 178   Project Narrative The proposed study seeks to ...
# 363   Ewing Sarcoma (ES) is an aggressive tumor ofte...
# 523   PROJECT NARRATIVEThe three-dimensional (3D) ge...
# 539   PROJECT NARRATIVEOur project aims to refine a ...
#
#                          Department Organization ID (IPF)  \
# 929            OTHER BASIC SCIENCES               7596201
# 1179                   BIOCHEMISTRY               7636101
# 693                     Unavailable              10061137
# 689                     Unavailable              10004881
# 735                    NEUROSURGERY               2221101
# 761                     Unavailable               2988701
# 1250                    Unavailable               2988701
# 754                     Unavailable               2988701
# 691                     Unavailable               2988701
# 682                     Unavailable               2988701
# 82                      Unavailable               3058203
# 674                    PHARMACOLOGY               4679701
# 1446     INTERNAL MEDICINE/MEDICINE               9420201
# 1331                           NONE               6218701
# 1126  RADIATION-DIAGNOSTIC/ONCOLOGY                577504
# 655                     Unavailable               7375802
# 178         OBSTETRICS & GYNECOLOGY                578407
# 363                    BIOCHEMISTRY               2869001
# 523                        GENETICS               9420201
# 539         ENGINEERING (ALL TYPES)               2021601
#
#                                   Organization Name Organization City  \
# 929                      UNIVERSITY OF SOUTH DAKOTA        VERMILLION
# 1179              UNIVERSITY OF SOUTHERN CALIFORNIA       Los Angeles
# 693   AMERICAN SOCIETY OF PREVENTIVE ONCOLOGY, INC.      INDIANAPOLIS
# 689        AMERICAN SOCIETY/INVESTIGATIVE PATHOLOGY         ROCKVILLE
# 735                                 DUKE UNIVERSITY            DURHAM
# 761                     GORDON RESEARCH CONFERENCES    East Greenwich
# 1250                    GORDON RESEARCH CONFERENCES    East Greenwich
# 754                     GORDON RESEARCH CONFERENCES    East Greenwich
# 691                     GORDON RESEARCH CONFERENCES    East Greenwich
# 682                     GORDON RESEARCH CONFERENCES    East Greenwich
# 82          BECKMAN RESEARCH INSTITUTE/CITY OF HOPE            DUARTE
# 674                        UNIVERSITY OF LOUISVILLE        LOUISVILLE
# 1446                                YALE UNIVERSITY         NEW HAVEN
# 1331                          OHIO STATE UNIVERSITY          COLUMBUS
# 1126                UNIVERSITY OF CALIFORNIA-IRVINE            IRVINE
# 655                 SCRIPPS RESEARCH INSTITUTE, THE          LA JOLLA
# 178            UNIVERSITY OF TX MD ANDERSON CAN CTR           HOUSTON
# 363                           GEORGETOWN UNIVERSITY        WASHINGTON
# 523                                 YALE UNIVERSITY         NEW HAVEN
# 539                               DARTMOUTH COLLEGE           HANOVER
#
#      Organization State              Organization Type Organization Country  \
# 929                  SD            SCHOOLS OF MEDICINE        UNITED STATES
# 1179                 CA               GRADUATE SCHOOLS        UNITED STATES
# 693                  IN     Other Domestic Non-Profits        UNITED STATES
# 689                  MD     Other Domestic Non-Profits        UNITED STATES
# 735                  NC            SCHOOLS OF MEDICINE        UNITED STATES
# 761                  RI           Domestic For-Profits        UNITED STATES
# 1250                 RI           Domestic For-Profits        UNITED STATES
# 754                  RI           Domestic For-Profits        UNITED STATES
# 691                  RI           Domestic For-Profits        UNITED STATES
# 682                  RI           Domestic For-Profits        UNITED STATES
# 82                   CA            Research Institutes        UNITED STATES
# 674                  KY            SCHOOLS OF MEDICINE        UNITED STATES
# 1446                 CT            SCHOOLS OF MEDICINE        UNITED STATES
# 1331                 OH       ORGANIZED RESEARCH UNITS        UNITED STATES
# 1126                 CA            SCHOOLS OF MEDICINE        UNITED STATES
# 655                  CA     Other Domestic Non-Profits        UNITED STATES
# 178                  TX                      HOSPITALS        UNITED STATES
# 363                  DC            SCHOOLS OF MEDICINE        UNITED STATES
# 523                  CT            SCHOOLS OF MEDICINE        UNITED STATES
# 539                  NH  BIOMED ENGR/COL ENGR/ENGR STA        UNITED STATES
#
#      Total Cost Total Cost (Sub Projects) Funding IC(s) Direct Cost IC  \
# 929       74750                                     NCI          50000
# 1179       7000                                     NCI           5000
# 693       40000                                     NCI          40000
# 689       15000                                     NCI          15000
# 735       16317                                     NCI          16317
# 761       15000                                     NCI          15000
# 1250      15000                                     NCI          15000
# 754       20000                                     NCI          15000
# 691       25000                                     NCI          18000
# 682        5000                                     NCI           5000
# 82        10000                                     NCI          10000
# 674       15000                                     NCI          15000
# 1446     430684                                     NCI         257125
# 1331      10000                                     NCI           5000
# 1126     641155                                     NCI         510313
# 655      240092                                     NCI         130485
# 178     1004570                                     NCI         713019
# 363      401115                                     NCI         257125
# 523      695123                                     NCI         414999
# 539      549536                                     NCI         348942
#
#      InDirect Cost IC Total Cost IC
# 929             24750         74750
# 1179                0          5000
# 693                 0         40000
# 689                 0         15000
# 735                 0         16317
# 761                 0         15000
# 1250                0         15000
# 754                 0         15000
# 691                 0         18000
# 682                 0          5000
# 82                  0         10000
# 674                 0         15000
# 1446           173559        430684
# 1331                0          5000
# 1126           130842        641155
# 655            109607        240092
# 178            291551       1004570
# 363            143990        401115
# 523            280124        695123
# 539            200594        549536

# %%
# prompt: bar graph by count of Organization Country

import matplotlib.pyplot as plt
# Count the occurrences of each country
country_counts = df2['Organization Name'].value_counts()

# Create the bar graph
plt.figure(figsize=(10, 6))  # Adjust figure size if needed
country_counts.plot(kind='bar')
plt.xlabel('Organization Name')
plt.ylabel('Count')
plt.title('Organizaiton Name')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent labels from overlapping
plt.show()

# %%
# prompt: create this graph again with only more than 10

import matplotlib.pyplot as plt
# Count the occurrences of each country
country_counts = df2['Organization Name'].value_counts()

# Filter out countries with less than or equal to 10 occurrences
country_counts_filtered = country_counts[country_counts > 20]

# Create the bar graph
plt.figure(figsize=(10, 6))  # Adjust figure size if needed
country_counts_filtered.plot(kind='bar')
plt.xlabel('Organization Name')
plt.ylabel('Count')
plt.title('Organizaiton Name (More than 10 occurrences)')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent labels from overlapping
plt.show()

# %%
from collections import Counter

def count_words(text):
    skips = [".", ", ", ":", ";", "'", '"', "and", "of", "the", "in", "a", "will", "for", "is", "that","re", " ", "to", "with", "tht", "by", "as", "on", "at", "from", "or", "it", "this", "its", "has", "have", "be", "but", "s", "an", "its"]
    for ch in skips:
        text = text.replace(ch, "")
    word_counts = Counter(text.split(" "))
    return word_counts

text = ' '.join(df2['Project Abstract'].astype(str).tolist())
counts = count_words(text)
print(counts.most_common(10))
# Out:
# [('AbtrcteDyNAmiC(extrchromoomlDNACncer)Humngenerrnged23pirchromoomecncertumour-promotggenecnfemelvechromoomeloctecirculrextrchromoomlpieceDNA(ecDNA)TheeecDNAdotfollownmlrulechromoomlhernceenblgtumourchievefrhigherlevelcncer-cugcogenethnwouldwepoiblelicengcncerwyevolvechngeirgenomeevdettmenttrtewouldunthkblehumncellTheltedcirculrrchectuecDNAlochngewycncer-cuggenegultedexpedfurrctrigggivetumourgrowthTheeuniquefetumkeecDNA-ctgcncerepecillyggivedifficultttCncerptientwhoetumourhrbourecDNAhvemrkedlyhterurvivlDepegfirteenoverfiftyyergocriclimptnceecDNAhlycentlycomelightcleproblemubtntilecDNApentnerlyhlfllhumncncertypepotentillyup-...-...-wldhelthcettgPrimryechllengelieirgulrmulti-(SDoH)impcthelthdpriemgwomenUSugtwoethnicllydiverewomenhelthdtetwhedtpenthighheterogeneymulti-olutifetuovertimeWeimflexiblyextrcteentilmtiheterogeneouignlcrohigh-dimenilomni-chnnelovertimetegrtemtimulti-olutivribleenhncepdictipcerptbilyWefurrtrgenleequentilpolicyoptimiztiproviden-viveterventtmentovertimemximizedividulhelthoutcomeccdgirheterogeneyInummryourerchim(1)Developdeepneurlmodelundertgpdictgdividulhelthovertimewhilelernghdptterncromultipledividulenhnceterptbilyult(2)Ctenoveldttegrtechniquemulti-olutimobilehelthdtccommodtgirgulrtimetervldiveremplgrtemeumentvrimgubject(3)Implementcementlerngpltmfdubject-pecificoptimlpolicieunderpopultilheterogeney(4)Applypropoedmethodidentifybiopychoocilfcrffectgwomenhelthenblgdevelopmenterlypventerventitrtegieenhnceoverllwell-gwomenTheoverrchgobjectivethprojectoptimizeperlizebtcncercengdvncgrtificiltelligence(AI)lghmBtcncermjgloblhelthccernErlydignokeyducgdeeburdenmtlymkgbtcncerefewcncergulrlycenedympmticwomenAccdglyAmericnCncerSocietycommendnnulcengwomenge40olderledgubtntilnumrcncductedyerlyMmmogrphynetimted39millinnulcengUSprimrybtcncercengmethodDiglBtTomoyn(DBT)3Dmmmogrphyhcomeroutecengmethod3DtueviewimprovgcncerdetectiHowevercomplexymmmogrmhighrdiologtwklodlowpvlencebtcncercengexmtichllengerdiologtpermncecerkflepoivemeddignoeComputer-ideddetecti(CAD)ytemhveentroducedtrdiologtufferhighflepoivetrghelthcytemcugneedlewryptientRecentdvncementdeeplerng(DL)ubfieldAIhveenbleddevelopmentnewCAD(AI-CAD)ytemcntrnmclicldeci-mkgHoweverAI-CADfcelimtiwhendelgDBTimgeCurntDLmodeltenlyjutcurntcnlckl-wldgenerlizbilytrugglehigh-olutiDICOMmtcomplexyDBTimgeToenhncebtcncercengwepropoemolticAI-CADytemwhichmimicrdiologtpprochbtcncercengcomprgcurntprimmmogrmcptgcliclrkfcrccountgimgecfigurtivriFurrmoweciderprcticlimplementtiuchytemcliclueThprojectimchievemobjectivethroughthepecificgoli)chieverobutexplbleefficientpenttiDBTimgecnceridentifictiemploygelfttentigrphlerngmodelii)developmultimodllgudllerngmodeltegrtghryimgecliclmtictgmohumn-liketelligenceCADytemimprovebtcncerdetectilocliztiiii)prcticllyimplementAI-CADcliclueutilizgexpert---loopctullerngenumodeldptivychngeprcticenlghm-hrdwcodeignmodelcompienucomputtilfeibilyFurrmoprojectprovidecompheniveDBTdtbeInthprojectbothpubliclyvilble--AtedInterventi(AAI)gol-ientedprogrmtentillycptenimluchdogrpeuticnefAAIwidelyuedvrietyettgepecillycncerptientwellveternPot-TrumticStDder(PTSD)AAIhprovenprovidephyiologiclpychologiclympmnefThepoiveeffectAAIpoedprtduedynmichumn-nimlbd(HAB)DepeAAIpopulryneircompheniveAAIementmethodntkeholder-medtrdizedAAIprocolextcludgctiviecriclundertgAAImechnmctiroleHABmechnmwhichHABmedmtedOuroverllobjectivedeveloptetevlutenternetthgtwhrdwytemdydicphyiologiclmirghumnnimlAAIettgnovtenlyticmethodterptgdtThewkimptntcfulyt ...

# %%
# prompt: return rows with project titles with "MATCHMAKERS"

df_matchmakers = df2[df2['Project Title'].str.contains('MATCHMAKERS', case=False)]
df_matchmakers.head(50)
# Out:
#                                         Project Title Contact PI Person ID  \
# 25  MATCHMAKERS - Solving TCR recognition and desi...             11974674
# 33  MATCHMAKERS - SOLVING TCR RECOGNITION AND DESI...             15788314
# 34  MATCHMAKERS - Solving T-cell receptor recognit...             14226120
# 35  MATCHMAKERS - large-scale generation of reacti...             14981981
# 42  MATCHMAKERS: Solving T-cell receptor recogniti...              1887701
# 44  MATCHMAKERS - Creating and training AI tools f...             10293339
# 46  MATCHMAKERS - Solving T-cell receptor recognit...             10661907
# 49                                        MATCHMAKERS              1955169
# 50  MATCHMAKERS: SOLVING TCR RECOGNITION AND DESIG...              6472797
# 52                                        MATCHMAKERS             11746917
# 54  MATCHMAKERS: Large-scale generation of TCR-pMH...             79629683
#
#    Contact PI / Project Leader  \
# 25        SGOURAKIS, NIKOLAOS
# 33            OLWEUS, JOHANNA
# 34      DEKOSKY, BRANDON JAMES
# 35            QUEZADA, SERGIO
# 42          ELLEDGE, STEPHEN J
# 44          BIRNBAUM, MICHAEL
# 46        BRUNO, PETER MICHAEL
# 49               BAKER, DAVID
# 50   GARCIA, KENAN CHRISTOPHER
# 52            SCHUMACHER, TON
# 54                BUSCH, DIRK
#
#                                      Project Abstract Public Health Relevance  \
# 25  AbstractUnderstanding how T cell receptors (TC...                     NaN
# 33  AbstractUnderstanding how T cell receptors (TC...                     NaN
# 34  AbstractUnderstanding how T cell receptors (TC...                     NaN
# 35  AbstractUnderstanding how T cell receptors (TC...                     NaN
# 42  AbstractUnderstanding how T cell receptors (TC...                     NaN
# 44  AbstractUnderstanding how T cell receptors (TC...                     NaN
# 46  ABSTRACT: UCSFUnderstanding how T cell recepto...                     NaN
# 49  AbstractUnderstanding how T cell receptors (TC...                     NaN
# 50  AbstractUnderstanding how T cell receptors (TC...                     NaN
# 52  AbstractUnderstanding how T cell receptors (TC...                     NaN
# 54  AbstractUnderstanding how T cell receptors (TC...                     NaN
#
#                     Department Organization ID (IPF)  \
# 25                 Unavailable               1499101
# 33                 Unavailable              10005923
# 34                 Unavailable               4907701
# 35                 Unavailable               3527409
# 42                 Unavailable               1080401
# 44               MISCELLANEOUS               4911501
# 46                     UROLOGY                577508
# 49                BIOCHEMISTRY               9087701
# 50  INTERNAL MEDICINE/MEDICINE               8046501
# 52                 Unavailable               5802601
# 54                 Unavailable               8227001
#
#                            Organization Name Organization City  \
# 25           CHILDREN'S HOSP OF PHILADELPHIA      PHILADELPHIA
# 33  OSLO UNIVERSITY HOSPITAL, RIKSHOSPITALET              OSLO
# 34            MASSACHUSETTS GENERAL HOSPITAL            BOSTON
# 35                 UNIVERSITY COLLEGE LONDON            LONDON
# 42              BRIGHAM AND WOMEN'S HOSPITAL            BOSTON
# 44     MASSACHUSETTS INSTITUTE OF TECHNOLOGY         CAMBRIDGE
# 46   UNIVERSITY OF CALIFORNIA, SAN FRANCISCO     SAN FRANCISCO
# 49                  UNIVERSITY OF WASHINGTON           SEATTLE
# 50                       STANFORD UNIVERSITY          STANFORD
# 52              NETHERLANDS CANCER INSTITUTE         AMSTERDAM
# 54            TECHNICAL UNIVERSITY OF MUNICH            MUNICH
#
#    Organization State         Organization Type Organization Country  \
# 25                 PA     Independent Hospitals        UNITED STATES
# 33                                  Unavailable               NORWAY
# 34                 MA     Independent Hospitals        UNITED STATES
# 35                                  Unavailable       UNITED KINGDOM
# 42                 MA     Independent Hospitals        UNITED STATES
# 44                 MA  ORGANIZED RESEARCH UNITS        UNITED STATES
# 46                 CA       SCHOOLS OF MEDICINE        UNITED STATES
# 49                 WA       SCHOOLS OF MEDICINE        UNITED STATES
# 50                 CA       SCHOOLS OF MEDICINE        UNITED STATES
# 52                                  Unavailable          NETHERLANDS
# 54                                  Unavailable              GERMANY
#
#    Total Cost Total Cost (Sub Projects) Funding IC(s) Direct Cost IC  \
# 25     248155                                     NCI         139413
# 33      74043                                     NCI          74043
# 34     233863                                     NCI         140038
# 35     169280                                     NCI         156741
# 42     289171                                     NCI         168227
# 44     681176                                     NCI         484249
# 46     160333                                     NCI          98013
# 49     327039                                     NCI         282715
# 50     214343                                     NCI         138823
# 52     167757                                     NCI         167757
# 54     191844                                     NCI         191844
#
#    InDirect Cost IC Total Cost IC
# 25           108742        248155
# 33                0         74043
# 34            93825        233863
# 35            12539        169280
# 42           120944        289171
# 44           196927        681176
# 46            62320        160333
# 49            44324        327039
# 50            75520        214343
# 52                0        167757
# 54                0        191844

# %%
# prompt: remove rows with duplicate abstracts but keep 1

df2 = df2.drop_duplicates(subset=['Project Abstract'], keep='first')
df_matchmakers = df2[df2['Project Title'].str.contains('MATCHMAKERS', case=False)]
df_matchmakers.head(50)
# Out:
#                                         Project Title Contact PI Person ID  \
# 25  MATCHMAKERS - Solving TCR recognition and desi...             11974674
# 33  MATCHMAKERS - SOLVING TCR RECOGNITION AND DESI...             15788314
# 34  MATCHMAKERS - Solving T-cell receptor recognit...             14226120
# 46  MATCHMAKERS - Solving T-cell receptor recognit...             10661907
#
#    Contact PI / Project Leader  \
# 25        SGOURAKIS, NIKOLAOS
# 33            OLWEUS, JOHANNA
# 34      DEKOSKY, BRANDON JAMES
# 46        BRUNO, PETER MICHAEL
#
#                                      Project Abstract Public Health Relevance  \
# 25  AbstractUnderstanding how T cell receptors (TC...                     NaN
# 33  AbstractUnderstanding how T cell receptors (TC...                     NaN
# 34  AbstractUnderstanding how T cell receptors (TC...                     NaN
# 46  ABSTRACT: UCSFUnderstanding how T cell recepto...                     NaN
#
#      Department Organization ID (IPF)  \
# 25  Unavailable               1499101
# 33  Unavailable              10005923
# 34  Unavailable               4907701
# 46      UROLOGY                577508
#
#                            Organization Name Organization City  \
# 25           CHILDREN'S HOSP OF PHILADELPHIA      PHILADELPHIA
# 33  OSLO UNIVERSITY HOSPITAL, RIKSHOSPITALET              OSLO
# 34            MASSACHUSETTS GENERAL HOSPITAL            BOSTON
# 46   UNIVERSITY OF CALIFORNIA, SAN FRANCISCO     SAN FRANCISCO
#
#    Organization State      Organization Type Organization Country Total Cost  \
# 25                 PA  Independent Hospitals        UNITED STATES     248155
# 33                               Unavailable               NORWAY      74043
# 34                 MA  Independent Hospitals        UNITED STATES     233863
# 46                 CA    SCHOOLS OF MEDICINE        UNITED STATES     160333
#
#    Total Cost (Sub Projects) Funding IC(s) Direct Cost IC InDirect Cost IC  \
# 25                                     NCI         139413           108742
# 33                                     NCI          74043                0
# 34                                     NCI         140038            93825
# 46                                     NCI          98013            62320
#
#    Total Cost IC
# 25        248155
# 33         74043
# 34        233863
# 46        160333

# %%
# prompt: count of rows in df2

print(len(df2))
# Out:
# 1448

# %%
# Assuming 'Project Abstract' contains information about cancer types
cancer_counts = df2['Project Abstract'].str.lower().str.findall(r'\b(breast cancer|leukemia|liver cancer|tumor)\b').explode().value_counts()

# Create the bar graph
plt.figure(figsize=(10, 6))
cancer_counts.plot(kind='bar')
plt.xlabel('Cancer Type')
plt.ylabel('Count')
plt.title('Count of Cancer Types')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# prompt: export column headers and descriptions

import pandas as pd
# Get the column headers and descriptions
column_headers = df2.columns.tolist()
column_descriptions = [df2[col].dtype for col in df2.columns]

# Create a DataFrame with headers and descriptions
header_description_df = pd.DataFrame({'Header': column_headers, 'Description': column_descriptions})

# Export the DataFrame to a CSV file
header_description_df.to_csv('column_headers_and_descriptions.csv', index=False)

# Optionally, you can print the DataFrame to see the content
print(header_description_df)
# Out:
#                          Header Description
# 0                 Project Title      object
# 1          Contact PI Person ID      object
# 2   Contact PI / Project Leader      object
# 3              Project Abstract      object
# 4       Public Health Relevance      object
# 5                    Department      object
# 6         Organization ID (IPF)      object
# 7             Organization Name      object
# 8             Organization City      object
# 9            Organization State      object
# 10            Organization Type      object
# 11         Organization Country      object
# 12                   Total Cost      object
# 13    Total Cost (Sub Projects)      object
# 14                Funding IC(s)      object
# 15               Direct Cost IC      object
# 16             InDirect Cost IC      object
# 17                Total Cost IC      object

# %%
# Assuming 'Project Abstract' contains information about cancer types
cancer_counts = df2['Project Abstract'].str.lower().str.findall(r'\b(Bladder Cancer|Breast Cancer|Colon Cancer|Rectal Cancer|Endometrial Cancer|Kidney Cancer|Leukemia|Liver|Lung Cancer|Melanoma|Non-Hodgkin Lymphoma|Pancreatic Cancer|Prostate Cancer|Thyroid Cancer)\b').explode().value_counts()

# Create the bar graph
plt.figure(figsize=(10, 6))
cancer_counts.plot(kind='bar')
plt.xlabel('Cancer Type')
plt.ylabel('Count')
plt.title('Count of Cancer Types')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-19-4d301aae9139> in <cell line: 6>()
#       4 # Create the bar graph
#       5 plt.figure(figsize=(10, 6))
# ----> 6 cancer_counts.plot(kind='bar')
#       7 plt.xlabel('Cancer Type')
#       8 plt.ylabel('Count')
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#    1029                     data.columns = label_name
#    1030
# -> 1031         return plot_backend.plot(data, kind=kind, **kwargs)
#    1032
#    1033     __call__.__doc__ = __doc__
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     458         for ax in self.axes:
#     459             self._post_plot_logic_common(ax, self.data)
# --> 460             self._post_plot_logic(ax, self.data)
#     461
#     462     @abstractmethod
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/core.py in _post_plot_logic(self, ax, data)
#    1755             str_index = [pprint_thing(key) for key in range(data.shape[0])]
#    1756
# -> 1757         s_edge = self.ax_pos[0] - 0.25 + self.lim_offset
#    1758         e_edge = self.ax_pos[-1] + 0.25 + self.bar_width + self.lim_offset
#    1759
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
# prompt: Create a similar bar graph with these words Bladder Cancer


import matplotlib.pyplot as plt
# Assuming 'Project Abstract' contains information about cancer types
cancer_counts = df2['Project Abstract'].str.lower().str.findall(r'\b(acute lymphoblastic leukemia\acute myeloid leukemia|anal cancer|adrenocortical carcinoma|breast cancer|brain cancer|bone cancer|bile duct cancer|colon and rectal cancer|colorectal cancer|cervical cancer|endometrial cancer|kidney cancer|leukemia|liver|lung cancer|melanoma|medulloblastoma|non-hodgkin lymphoma||pancreatic cancer||prostate cancer|skin cancer|thyroid cancer)\b').explode().value_counts()

# Create the bar graph
plt.figure(figsize=(10, 6))
cancer_counts.plot(kind='bar')
plt.xlabel('Cancer Type')
plt.ylabel('Count')
plt.title('Count of Cancer Types')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# prompt: now with this list: Adenoid Cystic Carcinoma
# Adrenal Gland Cancer
# Amyloidosis
# Anal Cancer
# Ataxia-Telangiectasia
# Atypical Mole Syndrome
# Basal Cell Carcinoma
# Bile Duct Cancer
# Birt Hogg Dube Syndrome
# Bladder Cancer
# Bone Cancer
# Brain Tumor
# Breast Cancer
# Breast Cancer in Men
# Carcinoid Tumor
# Cervical Cancer
# Colorectal Cancer
# Ductal Carcinoma
# Endometrial Cancer
# Esophageal Cancer
# Gastric Cancer
# Gastrontes

import matplotlib.pyplot as plt
cancer_types = [
    "Adenoid Cystic Carcinoma",
    "Adrenal Gland Cancer",
    "Amyloidosis",
    "Anal Cancer",
    "Ataxia-Telangiectasia",
    "Atypical Mole Syndrome",
    "Basal Cell Carcinoma",
    "Bile Duct Cancer",
    "Birt Hogg Dube Syndrome",
    "Bladder Cancer",
    "Bone Cancer",
    "Brain Tumor",
    "Breast Cancer",
    "Breast Cancer in Men",
    "Carcinoid Tumor",
    "Cervical Cancer",
    "Colorectal Cancer",
    "Ductal Carcinoma",
    "Endometrial Cancer",
    "Esophageal Cancer",
    "Gastric Cancer",
    "Gastrontes"
]

# Create a regular expression pattern to search for these cancer types
pattern = r'\b(' + '|'.join(cancer_types) + r')\b'

# Find the occurrences of each cancer type in the 'Project Abstract' column
cancer_counts = df2['Project Abstract'].str.lower().str.findall(pattern).explode().value_counts()

# Create the bar graph
plt.figure(figsize=(10, 6))
cancer_counts.plot(kind='bar')
plt.xlabel('Cancer Type')
plt.ylabel('Count')
plt.title('Count of Cancer Types')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-31-26e15765a7af> in <cell line: 58>()
#      56 # Create the bar graph
#      57 plt.figure(figsize=(10, 6))
# ---> 58 cancer_counts.plot(kind='bar')
#      59 plt.xlabel('Cancer Type')
#      60 plt.ylabel('Count')
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#    1029                     data.columns = label_name
#    1030
# -> 1031         return plot_backend.plot(data, kind=kind, **kwargs)
#    1032
#    1033     __call__.__doc__ = __doc__
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     458         for ax in self.axes:
#     459             self._post_plot_logic_common(ax, self.data)
# --> 460             self._post_plot_logic(ax, self.data)
#     461
#     462     @abstractmethod
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/core.py in _post_plot_logic(self, ax, data)
#    1755             str_index = [pprint_thing(key) for key in range(data.shape[0])]
#    1756
# -> 1757         s_edge = self.ax_pos[0] - 0.25 + self.lim_offset
#    1758         e_edge = self.ax_pos[-1] + 0.25 + self.bar_width + self.lim_offset
#    1759
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
# prompt: create a bar graph checkng for these words acute lymphoblastic leukemia\acute myeloid leukemia|anal cancer|adrenocortical carcinoma|breast cancer|brain cancer|bone cancer|bile duct cancer|colon and rectal cancer|colorectal cancer|cervical cancer|endometrial cancer|kidney cancer|leukemia|liver|lung cancer|melanoma|medulloblastoma|non-hodgkin lymphoma||pancreatic cancer||prostate cancer|skin cancer|

import matplotlib.pyplot as plt
cancer_types = [
    "acute lymphoblastic leukemia",
    "acute myeloid leukemia",
    "anal cancer",
    "adrenocortical carcinoma",
    "breast cancer",
    "brain cancer",
    "bone cancer",
    "bile duct cancer",
    "colon and rectal cancer",
    "colorectal cancer",
    "cervical cancer",
    "endometrial cancer",
    "kidney cancer",
    "leukemia",
    "liver",
    "lung cancer",
    "melanoma",
    "medulloblastoma",
    "non-hodgkin lymphoma",
    "pancreatic cancer",
    "prostate cancer",
    "skin cancer"
]

# Create a regular expression pattern to search for these cancer types
pattern = r'\b(' + '|'.join(cancer_types) + r')\b'

# Find the occurrences of each cancer type in the 'Project Abstract' column
cancer_counts = df2['Project Abstract'].str.lower().str.findall(pattern).explode().value_counts()

# Create the bar graph
plt.figure(figsize=(10, 6))
cancer_counts.plot(kind='bar')
plt.xlabel('Cancer Type')
plt.ylabel('Count')
plt.title('Count of Cancer Types')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# prompt: show counts of each bar and add color gradient

import matplotlib.pyplot as plt
import numpy as np
cancer_types = [
    "acute lymphoblastic leukemia",
    "acute myeloid leukemia",
    "anal cancer",
    "adrenocortical carcinoma",
    "breast cancer",
    "brain cancer",
    "bone cancer",
    "bile duct cancer",
    "colon and rectal cancer",
    "colorectal cancer",
    "cervical cancer",
    "endometrial cancer",
    "kidney cancer",
    "leukemia",
    "liver cancer",
    "lung cancer",
    "melanoma",
    "medulloblastoma",
    "non-hodgkin lymphoma",
    "pancreatic cancer",
    "prostate cancer",
    "skin cancer"
]

# Create a regular expression pattern to search for these cancer types
pattern = r'\b(' + '|'.join(cancer_types) + r')\b'

# Find the occurrences of each cancer type in the 'Project Abstract' column
cancer_counts = df2['Project Abstract'].str.lower().str.findall(pattern).explode().value_counts()

# Create the bar graph with counts and color gradient
plt.figure(figsize=(10, 6))
ax = cancer_counts.plot(kind='bar', color=plt.cm.viridis(np.linspace(0, 1, len(cancer_counts))))
plt.xlabel('Cancer Type')
plt.ylabel('Count')
plt.title('Count of Cancer Types')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Add counts on top of each bar
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 5), textcoords='offset points')

plt.show()

# %%
# prompt: create bar graph like this but bars should be counts of rows containing each word

import matplotlib.pyplot as plt
from collections import defaultdict

def count_rows_with_word(df, column, words):
  """
  Counts the number of rows in a DataFrame's column that contain each word.

  Args:
    df: The DataFrame to analyze.
    column: The column to search in.
    words: A list of words to search for.

  Returns:
    A dictionary mapping each word to its row count.
  """
  word_counts = defaultdict(int)
  for _, row in df.iterrows():
    text = str(row[column]).lower()
    for word in words:
      if word.lower() in text:
        word_counts[word] += 1
  return word_counts

# Example usage:
cancer_types = [
    "acute lymphoblastic leukemia",
    "acute myeloid leukemia",
    "anal cancer",
    "adrenocortical carcinoma",
    "breast cancer",
    "brain cancer",
    "bone cancer",
    "bile duct cancer",
    "colon and rectal cancer",
    "colorectal cancer",
    "cervical cancer",
    "endometrial cancer",
    "kidney cancer",
    "leukemia",
    "liver cancer",
    "lung cancer",
    "melanoma",
    "medulloblastoma",
    "non-hodgkin lymphoma",
    "pancreatic cancer",
    "prostate cancer",
    "skin cancer"
]

word_counts = count_rows_with_word(df2, 'Project Abstract', cancer_types)

# Create the bar graph
plt.figure(figsize=(10, 6))
plt.bar(word_counts.keys(), word_counts.values())
plt.xlabel('Cancer Type')
plt.ylabel('Row Count')
plt.title('Count of Rows Containing Cancer Types')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# prompt: do this again with counts on top and gradient coloring

import matplotlib.pyplot as plt
import numpy as np
cancer_types = [
    "acute lymphoblastic leukemia",
    "acute myeloid leukemia",
    "anal cancer",
    "adrenocortical carcinoma",
    "breast cancer",
    "brain cancer",
    "bone cancer",
    "bile duct cancer",
    "colon and rectal cancer",
    "colorectal cancer",
    "cervical cancer",
    "endometrial cancer",
    "kidney cancer",
    "leukemia",
    "liver cancer",
    "lung cancer",
    "melanoma",
    "medulloblastoma",
    "non-hodgkin lymphoma",
    "pancreatic cancer",
    "prostate cancer",
    "skin cancer"
]

word_counts = count_rows_with_word(df2, 'Project Abstract', cancer_types)

# Create the bar graph with counts and color gradient
plt.figure(figsize=(10, 6))
ax = plt.bar(word_counts.keys(), word_counts.values(), color=plt.cm.viridis(np.linspace(0, 1, len(word_counts))))
plt.xlabel('Cancer Type')
plt.ylabel('Row Count')
plt.title('Count of Rows Containing Cancer Types')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Add counts on top of each bar
for p in ax:
    height = p.get_height()
    plt.text(p.get_x() + p.get_width()/2., height, height, ha='center', va='bottom')


plt.show()

# %%
# prompt: create a similar bar graph looking for these words Biomarker testing
# Chemotherapy
# Hormone therapy
# Hyperthermia
# Immunotherapy
# Photodynamic therapy
# Radiation therapy
# Stem cell transplant
# Surgery
# Targeted drug therapy
# Clinical trials

import matplotlib.pyplot as plt
import numpy as np
treatment_types = [
    "Biomarker testing",
    "Chemotherapy",
    "Hormone therapy",
    "Hyperthermia",
    "Immunotherapy",
    "Photodynamic therapy",
    "Radiation therapy",
    "Stem cell transplant",
    "Surgery",
    "Targeted drug therapy",
    "Clinical trials"
]

word_counts = count_rows_with_word(df2, 'Project Abstract', treatment_types)

# Create the bar graph with counts and color gradient
plt.figure(figsize=(10, 6))
ax = plt.bar(word_counts.keys(), word_counts.values(), color=plt.cm.viridis(np.linspace(0, 1, len(word_counts))))
plt.xlabel('Treatment Type')
plt.ylabel('Row Count')
plt.title('Count of Rows Containing Treatment Types')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Add counts on top of each bar
for p in ax:
    height = p.get_height()
    plt.text(p.get_x() + p.get_width()/2., height, height, ha='center', va='bottom')

plt.show()

# %%
# Create a dictionary to store the total funding for each cancer type
cancer_funding = {}
for cancer_type in cancer_types:
  cancer_funding[cancer_type] = 0.0  # Initialize with 0.0

# Convert 'Total Cost' to numeric type
df2['Total Cost'] = pd.to_numeric(df2['Total Cost'])

# Iterate through the 'Project Abstract' column and find mentions of each cancer type
for index, row in df2.iterrows():
  abstract = str(row['Project Abstract']).lower()
  for cancer_type in cancer_types:
    if cancer_type in abstract:
      cancer_funding[cancer_type] += row['Total Cost']

# Create the bar graph with counts and color gradient
plt.figure(figsize=(15, 8))
plt.bar(cancer_funding.keys(), cancer_funding.values(), color=plt.cm.viridis(np.linspace(0, 1, len(cancer_funding))))
plt.xlabel('Cancer Type')
plt.ylabel('Total Funding')
plt.title('Total Funding by Cancer Type')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Add counts on top of each bar
for i, v in enumerate(cancer_funding.values()):
  plt.text(i, v, str(round(v, 2)), ha='center', va='bottom')

plt.show()
